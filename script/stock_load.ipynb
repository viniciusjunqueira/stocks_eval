# %%
import requests
import pandas as pd
import datetime
import matplotlib.pyplot as plt
from matplotlib import style
import numpy as np
#from alpha_vantage.timeseries import TimeSeries
import alpha_vantage
import ipywidgets as wg
from IPython.display import display
import alpha_vantage
import json
from pandas.io.json import json_normalize

# %%
api_key = "A0XMGRAF9EOBLRDJ"

# %%
def search_ativo(name,key):
    url='https://www.alphavantage.co/query?function=SYMBOL_SEARCH&keywords='+name+'&apikey='+key
    data = requests.get(url)
    data = data.text
    data = json.loads(data)
    data=json_normalize(data['bestMatches'])
    print(data[['1. symbol', '2. name', '3. type','4. region','8. currency']])

# %%
search_ativo('itsa', key=api_key)
# Out:
#    1. symbol                           2. name      3. type         4. region  \
# 0      ITSAX   Transamerica Multi-Cap Growth A  Mutual Fund     United States
# 1  ITSA4.SAO  Itaúsa - Investimentos Itaú S.A.       Equity  Brazil/Sao Paolo
# 2  ITSA3.SAO  Itaúsa - Investimentos Itaú S.A.       Equity  Brazil/Sao Paolo
#
#   8. currency
# 0         USD
# 1         BRL
# 2         BRL

# %%
ativo = 'ITSA4.SAO'

# %%
ts = TimeSeries(key=api_key, output_format='pandas')

# %%
data, meta_data = ts.get_intraday(symbol=ativo, outputsize='full')

# %%
data
# Out:
#                      1. open  2. high  3. low  4. close  5. volume
# date
# 2018-12-10 07:00:00    12.12    12.15   12.10     12.10   278200.0
# 2018-12-10 07:15:00    12.10    12.11   12.06     12.10   948200.0
# 2018-12-10 07:30:00    12.10    12.10   12.05     12.08   485900.0
# 2018-12-10 07:45:00    12.08    12.12   12.08     12.11   311300.0
# 2018-12-10 08:00:00    12.10    12.12   12.05     12.07   450800.0
# 2018-12-10 08:15:00    12.07    12.07   11.94     11.96  1581200.0
# 2018-12-10 08:30:00    11.96    11.97   11.94     11.97   412000.0
# 2018-12-10 08:45:00    11.97    11.99   11.92     11.95   471900.0
# 2018-12-10 09:00:00    11.94    11.95   11.91     11.95   556200.0
# 2018-12-10 09:15:00    11.95    11.95   11.92     11.94   449800.0
# 2018-12-10 09:30:00    11.95    11.99   11.93     11.94   935200.0
# 2018-12-10 09:45:00    11.94    11.94   11.87     11.90   689500.0
# 2018-12-10 10:00:00    11.90    11.96   11.90     11.95   392200.0
# ...

# %%
data['4. close'].plot()
plt.title('Intraday Times Series for the '+ativo+' stock')
plt.show()

# %%
data, meta_data = ts.get_daily(symbol=ativo, outputsize='full')

# %%
data
# Out:
#             1. open  2. high   3. low  4. close   5. volume
# date
# 2000-01-03   1.0184   1.1436   1.0129    1.0837  10285107.0
# 2000-01-04   1.0456   1.0456   0.9802    0.9802  12071740.0
# 2000-01-05   0.9857   1.0619   0.9476    1.0619   9163033.0
# 2000-01-06   1.0565   1.0837   1.0510    1.0782  23085841.0
# 2000-01-07   1.0891   1.1055   1.0619    1.0728  11216095.0
# 2000-01-10   1.1000   1.1273   1.0946    1.1109  10982793.0
# 2000-01-11   1.1327   1.1327   1.1000    1.1055   7475579.0
# 2000-01-12   1.1164   1.1164   1.0728    1.0837   4151775.0
# 2000-01-13   1.1164   1.1218   1.0565    1.0619  10540225.0
# 2000-01-14   1.0674   1.0946   1.0510    1.0674  10676166.0
# 2000-01-17   1.0619   1.1218   1.0619    1.1055   5146997.0
# 2000-01-18   1.1055   1.1055   1.0619    1.0782   6336941.0
# 2000-01-19   1.0837   1.0837   1.0510    1.0674   5202142.0
# 2000-01-20   1.0619   1.0837   1.0347    1.0456   4388714.0
# 2000-01-21   1.0674   1.0674   1.0075    1.0238   3716681.0
# ...

# %%
data['4. close'].plot()
plt.title('Intraday Times Series for the '+ativo+' stock')
plt.show()
